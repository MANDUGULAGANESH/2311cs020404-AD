# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
data={"color":["green","yellow","orange","red","blue"]}
df=pd.DataFrame(data)
df
# Out:
#     color
# 0   green
# 1  yellow
# 2  orange
# 3     red
# 4    blue

# %%
label_en=LabelEncoder()
df["color_label"]=label_en.fit_transform(df["color"])
df
# Out:
#     color  color_label
# 0   green            1
# 1  yellow            4
# 2  orange            2
# 3     red            3
# 4    blue            0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['color_label'].plot(kind='hist', bins=20, title='color_label')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('color').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['color_label'].plot(kind='line', figsize=(8, 4), title='color_label')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_3['color'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_3, x='color_label', y='color', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
one_hot_en=OneHotEncoder(sparse_output=False)
one_hot_array=one_hot_en.fit_transform(df[['color']])
one_hot_df=pd.DataFrame(one_hot_array,columns=one_hot_en.get_feature_names_out())
df=pd.concat([df,one_hot_df],axis=1)
df
# Out:
#     color  color_label  color_blue  color_green  color_orange  color_red  \
# 0   green            1         0.0          1.0           0.0        0.0
# 1  yellow            4         0.0          0.0           0.0        0.0
# 2  orange            2         0.0          0.0           1.0        0.0
# 3     red            3         0.0          0.0           0.0        1.0
# 4    blue            0         1.0          0.0           0.0        0.0
#
#    color_yellow
# 0           0.0
# 1           1.0
# 2           0.0
# 3           0.0
# 4           0.0
